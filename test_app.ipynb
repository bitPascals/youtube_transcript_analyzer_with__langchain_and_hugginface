# %%
from youtube_transcript_api import YouTubeTranscriptApi
from youtube_comment_downloader import YoutubeCommentDownloader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain.chains import create_retrieval_chain
from langchain_core.prompts import ChatPromptTemplate
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.prompts import PromptTemplate
from langchain.vectorstores import Chroma
from langchain_groq import ChatGroq
from dotenv import load_dotenv
import re
import os
import dotenv

# %%
load_dotenv()

groq_api_key = os.getenv("GROQ_API_KEY")
os.environ["HF_TOKEN"] = os.getenv("HF_TOKEN")

# %%
llm  = ChatGroq(api_key=groq_api_key, model_name="llama3-8b-8192")

# %%
# Function to get youtube transcript from a video url

def get_transcript_from_url(video_url):
    # Extract video ID from URL
    pattern = r"(?:v=|youtu\.be/)([a-zA-Z0-9_-]{11})"
    match = re.search(pattern, video_url)
    if not match:
        raise ValueError("Invalid YouTube video URL.")
    
    video_id = match.group(1)
    return YouTubeTranscriptApi.get_transcript(video_id)

# Example usage
video_url = "https://www.youtube.com/watch?v=TOGfR9j3Xnk"

transcript = get_transcript_from_url(video_url)
transcript_texts = [entry['text'] for entry in transcript]

# %%
# Extracting comments from the yourtube video
from youtube_comment_downloader import YoutubeCommentDownloader

downloader = YoutubeCommentDownloader()
comments = downloader.get_comments_from_url(video_url)
comment_texts = [c['text'] for c in comments]
comment_texts
# Out:
# ['❤❤from Algeria 🇩🇿 😍',
#  'Great tips on spanking butt cheeks',
#  'Egypt',
#  '🇹🇿 TANZANIA 🇹🇿,EAST AFRICA KARIBU ,HAKUNA MATATA .',
#  'interesting',
#  "Or how about we don't hurt our children",
#  'I’m a black man and I’ve had women over my knee and I spanked them with my hand.',
#  'please make a video on places that make her sexually active and to make her wet. thanks in advance',
#  'watching from kenya',
#  "Oh please, it's the women who call out to be spanked",
#  'Create a site for a visual demonstration',
#  'Aurelia I like your videos from Senegal 🇸🇳',
#  'Zambia',
#  'Good job\nNoone in Kenya can give you such lessons🎉🎉🎉🇰🇪🇰🇪🇰🇪🇰🇪🇰🇪🇰🇪',
#  'Sierra Leone',
#  'Thank you you are so special ❤🥰',
#  'super video learned much',
#  'Jamaican jamaican. My sister your doing an amazing job keep up the good work ✅🇯🇲',
#  'How to go down on a woman 😩',
#  'Does size really matter or technique of usage ?',
#  'Wow, what amazing teaching',
#  'Thank you for the information',
#  'Getting into his mind by expertly knocking down his psychological walls and making him tingle with feelings of pleasure, means you\'re doing it right. There are many so called "canned phrases" to make it happen, for example go’ogling something like Celestine Dessike\'s Words of Desire was the perfect formula for me',
#  "I didn't  really get what you mean by spanking",
#  'Sending Love ❤️\nFrom Sierra Leone 🇸🇱',
#  'You look pretty',
#  'Am Kumasi / Ghana and infact u really my counceller',
#  'How to give a girl a wege',
#  'This topic is really educating. Thanks',
#  'Make a video on how to deal with rejection!!',
#  'Liberia',
#  'Am watching you from Saudi Arabia and I enjoy your discussion, thank you very much Ijay',
#  'dom',
#  'Great info...much appreciate the details!',
#  'You are doing amazing job. It will be wonderful connecting with you on a personal level. Keep doing what you are doing. Reply how I can connect with you.',
#  'Am from Gambia watching you from Italy',
#  'Great topic that never gets talked about. You rock!',
#  'Land of Bob Marley',
#  'Love this look on you! You’re so pretty gurl',
#  '🍑💞',
#  'I will like to meet you',
#  "Make money and get jacked buddy.you don't need nobody to tell you bcos you already know the reason for the rejection.",
#  'You’re welcome',
#  'Thanks for watching dear',
#  'Thanks for watching',
#  'Thanks ❤',
#  'Nwanyi oma, Ndewo.',
#  'Great stuff. 👍',
#  'Thank you for sharing...very informative 👍',
#  'I need a woman this good.',
#  'True 💯👍🧠👏🍑❤️💯',
#  'Thanks',
#  'Thanks for watching']

# %%
# Transcript and comments chunks with timestamps info
transcript_texts
# Out:
# ['hey Champs welcome back to my Channel or',
#  'welcome to my channel if this is your',
#  "first time here today we'll be talking",
#  'about banking okay spanking those butt',
#  'cheeks using your Pam',
#  '[Music]',
#  'but first I want to say a big thank you',
#  'to everybody watching me from all over',
#  'the world last time I mentioned a few',
#  'countries and I told you guys to tell me',
#  "where you're from in the comment section",
#  'and I see people from Australia from',
#  'Barbados to Caribbeans in general I see',
#  'people from Thailand thank you guys so',
#  'much I see all of your comments and your',
#  'requests and someone particularly',
#  'requested for this video to make a video',
#  "on how to spank properly and that's why",
#  "I'm making this video so if you have any",
#  'special video requests feel free to drop',
#  'it in the comment section I will try and',
#  'make sure that I deliver it 101 okay but',
#  "guys if you know you're not subscribed",
#  'to my Channel please subscribe so you',
#  'can be part of this amazing Community',
#  'okay I drop videos every single day so',
#  'trust me you will never be bored so',
#  "we're talking about spanking to date we",
#  'are going to be talking about what is',
#  'spanking how to spank where to spank and',
#  'where not to spank now spanking is',
#  'actually just tapping the butt cheeks',
#  'especially the butt cheeks a lot of will',
#  'tell you that there are so many places',
#  "you can spank but since you're",
#  "introducing it or you're trying to",
#  'master it start with the butt cheeks and',
#  'there are so many things you can use to',
#  'spank like if you want to go full BDSM',
#  'and you know kinky and all of that there',
#  'are so many tools you can use the spank',
#  "but today we're talking about the basic",
#  'which is just using your palm to span',
#  'now spanking has to do with the skin a',
#  "lot of men don't know that the skin is",
#  'one of the most sensitive parts of a',
#  "woman's body it is very sensitive if you",
#  'take advantage of it in the bedroom you',
#  'give your woman maximum pleasure a lot',
#  'of you just jump into going to all of',
#  'the you know boobs nibs and vjj without',
#  'actually utilizing the skin which the',
#  'woman really likes every woman likes to',
#  'be touched okay and if you know how to',
#  'touch a woman properly and use her skin',
#  'you will give her amazing pleasure in',
#  'the bedroom now how do you introduce',
#  'spanking to your partner a lot of people',
#  'will see it or find it weird if you just',
#  'tell your girlfriend can I spank you or',
#  'baby spank me okay not everybody is bold',
#  'enough to use that word but how do you',
#  'introduce it to your partner you start',
#  'by you know communicating I always say',
#  "communication and communication doesn't",
#  'always have to be verbal you can',
#  'communicate by trying something very',
#  'light on them and reading your partnered',
#  'body to see how they you know receives',
#  'that kind of treatment so',
#  'you need to start by either tapping her',
#  'ass very gently or you know playing with',
#  "her butt now don't tap any part of her",
#  "body if you're just introducing it don't",
#  'have any other part of her body just tap',
#  'her ass gently and see how she reacts to',
#  "you know if she doesn't like it she's",
#  'going to verbally tell you stop or she',
#  "doesn't like it she's just going to like",
#  "switch maybe she's giving you like a",
#  'doggy position she might just turn and',
#  'then you see it from her body that she',
#  "doesn't enjoy it or she doesn't like it",
#  'okay so you need to learn how to read',
#  "your partner's body to know because",
#  'spanking is about you know tapping the',
#  'skin and a lot of people have gone',
#  'through domestic violence and you know',
#  'rough relationships and they might not',
#  'feel very comfortable when you try to',
#  'hit them because they are going to see',
#  "it as hitting they're not going to see",
#  "it like it's you know fun thing to do so",
#  'you need to be very careful you need to',
#  'also have known your partner to know if',
#  'they pass through some kind of domestic',
#  'violence and you know just watch how',
#  'they react and once a woman says no',
#  "please no it's no it's non-negotiable",
#  "you don't want to cast any harm to to",
#  "your woman okay you don't want to make",
#  'your woman comfortable so she says no',
#  'Then respect existence and the next',
#  'thing you need to know is',
#  "spanking is all about tapping it's not",
#  "slap you're not hitting her to hurt her",
#  "you're tapping you're just tapping very",
#  "lightly you are tapping you're going to",
#  "be tapping the skin you're not going to",
#  "be slapping the skin because you don't",
#  'want to cause so much pains okay so',
#  'learn to understand that uh spanking is',
#  "not all about going like this it's all",
#  "about going like this okay you're not",
#  "going to fully do this you're going to",
#  "start by doing this you're just going to",
#  "start with this you're going to start",
#  'with this before you fully go into doing',
#  'this now how do you spank you have to',
#  'start by caressing that part of body you',
#  'want to spank now like with every part',
#  'of her body that is sensitive especially',
#  'her G-spot and her clits when you want',
#  'to give her a G-spot orgasm or a cleats',
#  'orgasm you need to caress that part here',
#  'you need to correct it enough so that',
#  'blood goes straight to that partner like',
#  'the crates for you to give an orgasm you',
#  'need to caress it you need to suck you',
#  'need to kiss you need to make the blood',
#  'pump into that you know small penis kind',
#  'of head until it is very very sensitive',
#  'and then you can give an organs in the',
#  'same way it is with the G-Spot so when',
#  'it comes to spanking the butt you need',
#  'to have prepared',
#  "okay I'll put it that way you need to",
#  'have prepared the Bots to receive that',
#  'little tab okay so you must have caress',
#  'you must have kissed you must have given',
#  'her some love bites very gently very',
#  'smoothly you must have licked her up she',
#  'must have been feeling that sensation',
#  'moving towards her but before you can',
#  'spank now before I even tell you how to',
#  'tap where exactly do you spank you have',
#  'to spank completely on the butt cheek',
#  "you know where the fat is that's where",
#  "you're going to spank okay avoid any",
#  "part that has bones it's really painful",
#  "it's really uncomfortable nobody wants",
#  'that around the back side the lower',
#  "waist the ribs the pelvic area you don't",
#  'want to spank any of that all of those',
#  'places there are bones there and once',
#  'you tap on that area with bone there is',
#  "no form of sweetness that's going to",
#  'come from there so you need to',
#  'concentrate on her both cheeks okay she',
#  'has two butt cheeks so just learn how to',
#  'tap it now the sweetest place you can',
#  'tap on is directly on the butt cheeks or',
#  'below the butt cheeks okay below the',
#  'butt cheek that is just very close to',
#  'the tie to the lower tie okay so you',
#  'know I cannot use sex toys let me just',
#  'put this out there because a lot of',
#  'people have been saying oh we need',
#  'visuals we need visuals YouTube has a',
#  'lot of restrictions and I will not want',
#  'my videos to be taken down okay so',
#  "please bear with me that's why I always",
#  "use my hands so let's do this",
#  'so if this is the butt cheeks of your',
#  "woman I'm guessing it's very big okay so",
#  'this is the butt cheek of your woman',
#  'this is the Lower Side so all of this is',
#  'her legs okay so this is the lower part',
#  'of her body so you can eat it you can',
#  'tap on the butt cheeks under the butt',
#  'cheeks on top of the butt cheeks and on',
#  'the lower part of the butt cheeks now',
#  "don't tap on the waist region okay tap",
#  'on the butt cheeks okay and the lower',
#  'part of the butt Chef so you tap like',
#  "this okay you tap like this since you're",
#  'introducing you tap like this so before',
#  'you start tapping you have to massage so',
#  'you massage all of this gently both butt',
#  'cheeks okay you can rest your keys you',
#  'leak you smoosh you put her in that mood',
#  "okay before you begin to tap and don't",
#  'tap continuously',
#  "okay don't tap continuously and learn",
#  'how to switch it now you tap a little on',
#  'this butt cheek you tap a little on the',
#  "other button because you don't want to",
#  'keep hitting on the particular place',
#  "it's only going to make it look too red",
#  'and it might start getting really',
#  'painful so make sure you switch from',
#  'this that good thing she has to watch it',
#  'so switch from these butt cheeks to this',
#  "butt cheek okay and don't do it",
#  'immediately create a little anticipation',
#  'now with sex you always want to create',
#  'anticipation you want her to to want it',
#  "but not knowing when it's going to come",
#  'okay you want her to want you to spank',
#  'her but not know when it comes out when',
#  'it comes it comes with that extra',
#  'excitement because she wants it and but',
#  "she doesn't know when it's gonna come so",
#  'when you tap',
#  'give a little anticipation before you',
#  'tap again and let me tell you what this',
#  'tapping does to the woman that makes it',
#  'really sweet and almost every woman',
#  "wants to be spanked especially when it's",
#  'you know the sex is already so good and',
#  "all of that now when you tap the woman's",
#  "butt like you know the woman's butt is",
#  'very close to her JJ okay the video is',
#  'just like down here already okay so when',
#  'you spark when you spank these chicks',
#  'okay it creates some kind of vibration',
#  'directly to the vjj it makes her Jack a',
#  'little it makes her feel good it gives',
#  'her goosebumps and if a woman is someone',
#  "who really Mourns she's gonna let out",
#  "very very sweet ignorance and that's why",
#  'when she starts enjoying it she keeps',
#  'telling you baby spanking',
#  'baby spank me so in summary the things',
#  'you have to remember our spanking is is',
#  "you don't have to be kinky or overly",
#  'spoiled or doing BDSM before you can',
#  'introduce banking to your partner it is',
#  'a tap it is not slaps okay it is a',
#  'gentle tap on the butt cheeks and',
#  'especially on the butt cheeks you need',
#  'to avoid every area that has bones the',
#  'pelvic the lower back you know every',
#  'part of our body that has bones you need',
#  'to avoid it and then most importantly',
#  "you need to watch your partner's body",
#  "movement some people don't like spanking",
#  'because it reminds them of a time in',
#  "their life or they didn't feel safe",
#  'domestic violence all of that all of',
#  'that so you need to watch your partners',
#  'uh you know mood when you spank I know',
#  'if they really like it or not and last',
#  'but not the least you need to learn how',
#  'to caress kiss and you know play with',
#  'the butts chicks before you go straight',
#  "into spanking so that's all for today I",
#  'hope you found it educative as well as',
#  'very in entertaining and yes exactly',
#  'record in my car today because',
#  'I have visitors in the house and I',
#  'really needed to make this video so I',
#  'rushed my car to make sure I recorded',
#  'this so guys drop your suggestions in',
#  'the comment section drop topics you want',
#  'me to research and you know make videos',
#  "about and I am I'll be more than willing",
#  'to create all of these amazing videos',
#  'for you because I see that you all enjoy',
#  'it and if I still speak really fast',
#  "please let me know because I've also",
#  'received comments like I speak fast and',
#  "sometimes you guys don't hear me",
#  "properly but I'm definitely gonna try to",
#  'you know make it you know meet everybody',
#  'halfway even though I know I cannot',
#  "please everybody but I'm going to try my",
#  'best to meet everybody halfway so until',
#  "next time if you're not subscribed guys",
#  "don't forget to click on the Subscribe",
#  'button click on that Bell to get',
#  'notified when I post my videos I upload',
#  'videos every single day so until next',
#  'time give this video a thumbs up share',
#  'it to people who need to see it so stay',
#  'loved stay beautiful and bye for now',
#  '[Music]',
#  'foreign',
#  '[Music]']

# %%
all_chunks = transcript_texts + comment_texts
all_chunks
# Out:
# ['hey Champs welcome back to my Channel or',
#  'welcome to my channel if this is your',
#  "first time here today we'll be talking",
#  'about banking okay spanking those butt',
#  'cheeks using your Pam',
#  '[Music]',
#  'but first I want to say a big thank you',
#  'to everybody watching me from all over',
#  'the world last time I mentioned a few',
#  'countries and I told you guys to tell me',
#  "where you're from in the comment section",
#  'and I see people from Australia from',
#  'Barbados to Caribbeans in general I see',
#  'people from Thailand thank you guys so',
#  'much I see all of your comments and your',
#  'requests and someone particularly',
#  'requested for this video to make a video',
#  "on how to spank properly and that's why",
#  "I'm making this video so if you have any",
#  'special video requests feel free to drop',
#  'it in the comment section I will try and',
#  'make sure that I deliver it 101 okay but',
#  "guys if you know you're not subscribed",
#  'to my Channel please subscribe so you',
#  'can be part of this amazing Community',
#  'okay I drop videos every single day so',
#  'trust me you will never be bored so',
#  "we're talking about spanking to date we",
#  'are going to be talking about what is',
#  'spanking how to spank where to spank and',
#  'where not to spank now spanking is',
#  'actually just tapping the butt cheeks',
#  'especially the butt cheeks a lot of will',
#  'tell you that there are so many places',
#  "you can spank but since you're",
#  "introducing it or you're trying to",
#  'master it start with the butt cheeks and',
#  'there are so many things you can use to',
#  'spank like if you want to go full BDSM',
#  'and you know kinky and all of that there',
#  'are so many tools you can use the spank',
#  "but today we're talking about the basic",
#  'which is just using your palm to span',
#  'now spanking has to do with the skin a',
#  "lot of men don't know that the skin is",
#  'one of the most sensitive parts of a',
#  "woman's body it is very sensitive if you",
#  'take advantage of it in the bedroom you',
#  'give your woman maximum pleasure a lot',
#  'of you just jump into going to all of',
#  'the you know boobs nibs and vjj without',
#  'actually utilizing the skin which the',
#  'woman really likes every woman likes to',
#  'be touched okay and if you know how to',
#  'touch a woman properly and use her skin',
#  'you will give her amazing pleasure in',
#  'the bedroom now how do you introduce',
#  'spanking to your partner a lot of people',
#  'will see it or find it weird if you just',
#  'tell your girlfriend can I spank you or',
#  'baby spank me okay not everybody is bold',
#  'enough to use that word but how do you',
#  'introduce it to your partner you start',
#  'by you know communicating I always say',
#  "communication and communication doesn't",
#  'always have to be verbal you can',
#  'communicate by trying something very',
#  'light on them and reading your partnered',
#  'body to see how they you know receives',
#  'that kind of treatment so',
#  'you need to start by either tapping her',
#  'ass very gently or you know playing with',
#  "her butt now don't tap any part of her",
#  "body if you're just introducing it don't",
#  'have any other part of her body just tap',
#  'her ass gently and see how she reacts to',
#  "you know if she doesn't like it she's",
#  'going to verbally tell you stop or she',
#  "doesn't like it she's just going to like",
#  "switch maybe she's giving you like a",
#  'doggy position she might just turn and',
#  'then you see it from her body that she',
#  "doesn't enjoy it or she doesn't like it",
#  'okay so you need to learn how to read',
#  "your partner's body to know because",
#  'spanking is about you know tapping the',
#  'skin and a lot of people have gone',
#  'through domestic violence and you know',
#  'rough relationships and they might not',
#  'feel very comfortable when you try to',
#  'hit them because they are going to see',
#  "it as hitting they're not going to see",
#  "it like it's you know fun thing to do so",
#  'you need to be very careful you need to',
#  'also have known your partner to know if',
#  'they pass through some kind of domestic',
#  'violence and you know just watch how',
#  'they react and once a woman says no',
#  "please no it's no it's non-negotiable",
#  "you don't want to cast any harm to to",
#  "your woman okay you don't want to make",
#  'your woman comfortable so she says no',
#  'Then respect existence and the next',
#  'thing you need to know is',
#  "spanking is all about tapping it's not",
#  "slap you're not hitting her to hurt her",
#  "you're tapping you're just tapping very",
#  "lightly you are tapping you're going to",
#  "be tapping the skin you're not going to",
#  "be slapping the skin because you don't",
#  'want to cause so much pains okay so',
#  'learn to understand that uh spanking is',
#  "not all about going like this it's all",
#  "about going like this okay you're not",
#  "going to fully do this you're going to",
#  "start by doing this you're just going to",
#  "start with this you're going to start",
#  'with this before you fully go into doing',
#  'this now how do you spank you have to',
#  'start by caressing that part of body you',
#  'want to spank now like with every part',
#  'of her body that is sensitive especially',
#  'her G-spot and her clits when you want',
#  'to give her a G-spot orgasm or a cleats',
#  'orgasm you need to caress that part here',
#  'you need to correct it enough so that',
#  'blood goes straight to that partner like',
#  'the crates for you to give an orgasm you',
#  'need to caress it you need to suck you',
#  'need to kiss you need to make the blood',
#  'pump into that you know small penis kind',
#  'of head until it is very very sensitive',
#  'and then you can give an organs in the',
#  'same way it is with the G-Spot so when',
#  'it comes to spanking the butt you need',
#  'to have prepared',
#  "okay I'll put it that way you need to",
#  'have prepared the Bots to receive that',
#  'little tab okay so you must have caress',
#  'you must have kissed you must have given',
#  'her some love bites very gently very',
#  'smoothly you must have licked her up she',
#  'must have been feeling that sensation',
#  'moving towards her but before you can',
#  'spank now before I even tell you how to',
#  'tap where exactly do you spank you have',
#  'to spank completely on the butt cheek',
#  "you know where the fat is that's where",
#  "you're going to spank okay avoid any",
#  "part that has bones it's really painful",
#  "it's really uncomfortable nobody wants",
#  'that around the back side the lower',
#  "waist the ribs the pelvic area you don't",
#  'want to spank any of that all of those',
#  'places there are bones there and once',
#  'you tap on that area with bone there is',
#  "no form of sweetness that's going to",
#  'come from there so you need to',
#  'concentrate on her both cheeks okay she',
#  'has two butt cheeks so just learn how to',
#  'tap it now the sweetest place you can',
#  'tap on is directly on the butt cheeks or',
#  'below the butt cheeks okay below the',
#  'butt cheek that is just very close to',
#  'the tie to the lower tie okay so you',
#  'know I cannot use sex toys let me just',
#  'put this out there because a lot of',
#  'people have been saying oh we need',
#  'visuals we need visuals YouTube has a',
#  'lot of restrictions and I will not want',
#  'my videos to be taken down okay so',
#  "please bear with me that's why I always",
#  "use my hands so let's do this",
#  'so if this is the butt cheeks of your',
#  "woman I'm guessing it's very big okay so",
#  'this is the butt cheek of your woman',
#  'this is the Lower Side so all of this is',
#  'her legs okay so this is the lower part',
#  'of her body so you can eat it you can',
#  'tap on the butt cheeks under the butt',
#  'cheeks on top of the butt cheeks and on',
#  'the lower part of the butt cheeks now',
#  "don't tap on the waist region okay tap",
#  'on the butt cheeks okay and the lower',
#  'part of the butt Chef so you tap like',
#  "this okay you tap like this since you're",
#  'introducing you tap like this so before',
#  'you start tapping you have to massage so',
#  'you massage all of this gently both butt',
#  'cheeks okay you can rest your keys you',
#  'leak you smoosh you put her in that mood',
#  "okay before you begin to tap and don't",
#  'tap continuously',
#  "okay don't tap continuously and learn",
#  'how to switch it now you tap a little on',
#  'this butt cheek you tap a little on the',
#  "other button because you don't want to",
#  'keep hitting on the particular place',
#  "it's only going to make it look too red",
#  'and it might start getting really',
#  'painful so make sure you switch from',
#  'this that good thing she has to watch it',
#  'so switch from these butt cheeks to this',
#  "butt cheek okay and don't do it",
#  'immediately create a little anticipation',
#  'now with sex you always want to create',
#  'anticipation you want her to to want it',
#  "but not knowing when it's going to come",
#  'okay you want her to want you to spank',
#  'her but not know when it comes out when',
#  'it comes it comes with that extra',
#  'excitement because she wants it and but',
#  "she doesn't know when it's gonna come so",
#  'when you tap',
#  'give a little anticipation before you',
#  'tap again and let me tell you what this',
#  'tapping does to the woman that makes it',
#  'really sweet and almost every woman',
#  "wants to be spanked especially when it's",
#  'you know the sex is already so good and',
#  "all of that now when you tap the woman's",
#  "butt like you know the woman's butt is",
#  'very close to her JJ okay the video is',
#  'just like down here already okay so when',
#  'you spark when you spank these chicks',
#  'okay it creates some kind of vibration',
#  'directly to the vjj it makes her Jack a',
#  'little it makes her feel good it gives',
#  'her goosebumps and if a woman is someone',
#  "who really Mourns she's gonna let out",
#  "very very sweet ignorance and that's why",
#  'when she starts enjoying it she keeps',
#  'telling you baby spanking',
#  'baby spank me so in summary the things',
#  'you have to remember our spanking is is',
#  "you don't have to be kinky or overly",
#  'spoiled or doing BDSM before you can',
#  'introduce banking to your partner it is',
#  'a tap it is not slaps okay it is a',
#  'gentle tap on the butt cheeks and',
#  'especially on the butt cheeks you need',
#  'to avoid every area that has bones the',
#  'pelvic the lower back you know every',
#  'part of our body that has bones you need',
#  'to avoid it and then most importantly',
#  "you need to watch your partner's body",
#  "movement some people don't like spanking",
#  'because it reminds them of a time in',
#  "their life or they didn't feel safe",
#  'domestic violence all of that all of',
#  'that so you need to watch your partners',
#  'uh you know mood when you spank I know',
#  'if they really like it or not and last',
#  'but not the least you need to learn how',
#  'to caress kiss and you know play with',
#  'the butts chicks before you go straight',
#  "into spanking so that's all for today I",
#  'hope you found it educative as well as',
#  'very in entertaining and yes exactly',
#  'record in my car today because',
#  'I have visitors in the house and I',
#  'really needed to make this video so I',
#  'rushed my car to make sure I recorded',
#  'this so guys drop your suggestions in',
#  'the comment section drop topics you want',
#  'me to research and you know make videos',
#  "about and I am I'll be more than willing",
#  'to create all of these amazing videos',
#  'for you because I see that you all enjoy',
#  'it and if I still speak really fast',
#  "please let me know because I've also",
#  'received comments like I speak fast and',
#  "sometimes you guys don't hear me",
#  "properly but I'm definitely gonna try to",
#  'you know make it you know meet everybody',
#  'halfway even though I know I cannot',
#  "please everybody but I'm going to try my",
#  'best to meet everybody halfway so until',
#  "next time if you're not subscribed guys",
#  "don't forget to click on the Subscribe",
#  'button click on that Bell to get',
#  'notified when I post my videos I upload',
#  'videos every single day so until next',
#  'time give this video a thumbs up share',
#  'it to people who need to see it so stay',
#  'loved stay beautiful and bye for now',
#  '[Music]',
#  'foreign',
#  '[Music]',
#  '❤❤from Algeria 🇩🇿 😍',
#  'Great tips on spanking butt cheeks',
#  'Egypt',
#  '🇹🇿 TANZANIA 🇹🇿,EAST AFRICA KARIBU ,HAKUNA MATATA .',
#  'interesting',
#  "Or how about we don't hurt our children",
#  'I’m a black man and I’ve had women over my knee and I spanked them with my hand.',
#  'please make a video on places that make her sexually active and to make her wet. thanks in advance',
#  'watching from kenya',
#  "Oh please, it's the women who call out to be spanked",
#  'Create a site for a visual demonstration',
#  'Aurelia I like your videos from Senegal 🇸🇳',
#  'Zambia',
#  'Good job\nNoone in Kenya can give you such lessons🎉🎉🎉🇰🇪🇰🇪🇰🇪🇰🇪🇰🇪🇰🇪',
#  'Sierra Leone',
#  'Thank you you are so special ❤🥰',
#  'super video learned much',
#  'Jamaican jamaican. My sister your doing an amazing job keep up the good work ✅🇯🇲',
#  'How to go down on a woman 😩',
#  'Does size really matter or technique of usage ?',
#  'Wow, what amazing teaching',
#  'Thank you for the information',
#  'Getting into his mind by expertly knocking down his psychological walls and making him tingle with feelings of pleasure, means you\'re doing it right. There are many so called "canned phrases" to make it happen, for example go’ogling something like Celestine Dessike\'s Words of Desire was the perfect formula for me',
#  "I didn't  really get what you mean by spanking",
#  'Sending Love ❤️\nFrom Sierra Leone 🇸🇱',
#  'You look pretty',
#  'Am Kumasi / Ghana and infact u really my counceller',
#  'How to give a girl a wege',
#  'This topic is really educating. Thanks',
#  'Make a video on how to deal with rejection!!',
#  'Liberia',
#  'Am watching you from Saudi Arabia and I enjoy your discussion, thank you very much Ijay',
#  'dom',
#  'Great info...much appreciate the details!',
#  'You are doing amazing job. It will be wonderful connecting with you on a personal level. Keep doing what you are doing. Reply how I can connect with you.',
#  'Am from Gambia watching you from Italy',
#  'Great topic that never gets talked about. You rock!',
#  'Land of Bob Marley',
#  'Love this look on you! You’re so pretty gurl',
#  '🍑💞',
#  'I will like to meet you',
#  "Make money and get jacked buddy.you don't need nobody to tell you bcos you already know the reason for the rejection.",
#  'You’re welcome',
#  'Thanks for watching dear',
#  'Thanks for watching',
#  'Thanks ❤',
#  'Nwanyi oma, Ndewo.',
#  'Great stuff. 👍',
#  'Thank you for sharing...very informative 👍',
#  'I need a woman this good.',
#  'True 💯👍🧠👏🍑❤️💯',
#  'Thanks',
#  'Thanks for watching']

# %%
# Splitting each chunk individually
final_chunks = []

from langchain.text_splitter import RecursiveCharacterTextSplitter

# Ensure 'all_chunks' is a single string or a list of strings
# If it's a list of strings (e.g. transcript list), join it:
all_text = " ".join(all_chunks) if isinstance(all_chunks, list) else all_chunks

# Create splitter
text_splitter = RecursiveCharacterTextSplitter(chunk_size=600, chunk_overlap=100)

# Split text
split_chunks = text_splitter.split_text(all_text)

# Collect chunks
final_chunks = split_chunks  # or use list(split_chunks) if it's a generator

# Print result
print(final_chunks)
# Out:
# ["hey Champs welcome back to my Channel or welcome to my channel if this is your first time here today we'll be talking about banking okay spanking those butt cheeks using your Pam [Music] but first I want to say a big thank you to everybody watching me from all over the world last time I mentioned a few countries and I told you guys to tell me where you're from in the comment section and I see people from Australia from Barbados to Caribbeans in general I see people from Thailand thank you guys so much I see all of your comments and your requests and someone particularly requested for this", "so much I see all of your comments and your requests and someone particularly requested for this video to make a video on how to spank properly and that's why I'm making this video so if you have any special video requests feel free to drop it in the comment section I will try and make sure that I deliver it 101 okay but guys if you know you're not subscribed to my Channel please subscribe so you can be part of this amazing Community okay I drop videos every single day so trust me you will never be bored so we're talking about spanking to date we are going to be talking about what is spanking", "be bored so we're talking about spanking to date we are going to be talking about what is spanking how to spank where to spank and where not to spank now spanking is actually just tapping the butt cheeks especially the butt cheeks a lot of will tell you that there are so many places you can spank but since you're introducing it or you're trying to master it start with the butt cheeks and there are so many things you can use to spank like if you want to go full BDSM and you know kinky and all of that there are so many tools you can use the spank but today we're talking about the basic which is", "that there are so many tools you can use the spank but today we're talking about the basic which is just using your palm to span now spanking has to do with the skin a lot of men don't know that the skin is one of the most sensitive parts of a woman's body it is very sensitive if you take advantage of it in the bedroom you give your woman maximum pleasure a lot of you just jump into going to all of the you know boobs nibs and vjj without actually utilizing the skin which the woman really likes every woman likes to be touched okay and if you know how to touch a woman properly and use her skin", "every woman likes to be touched okay and if you know how to touch a woman properly and use her skin you will give her amazing pleasure in the bedroom now how do you introduce spanking to your partner a lot of people will see it or find it weird if you just tell your girlfriend can I spank you or baby spank me okay not everybody is bold enough to use that word but how do you introduce it to your partner you start by you know communicating I always say communication and communication doesn't always have to be verbal you can communicate by trying something very light on them and reading your", "have to be verbal you can communicate by trying something very light on them and reading your partnered body to see how they you know receives that kind of treatment so you need to start by either tapping her ass very gently or you know playing with her butt now don't tap any part of her body if you're just introducing it don't have any other part of her body just tap her ass gently and see how she reacts to you know if she doesn't like it she's going to verbally tell you stop or she doesn't like it she's just going to like switch maybe she's giving you like a doggy position she might just", "like it she's just going to like switch maybe she's giving you like a doggy position she might just turn and then you see it from her body that she doesn't enjoy it or she doesn't like it okay so you need to learn how to read your partner's body to know because spanking is about you know tapping the skin and a lot of people have gone through domestic violence and you know rough relationshi ...

#  'many so called "canned phrases" to make it happen, for example go’ogling something like Celestine Dessike\'s Words of Desire was the perfect formula for me I didn\'t  really get what you mean by spanking Sending Love ❤️',
#  'From Sierra Leone 🇸🇱 You look pretty Am Kumasi / Ghana and infact u really my counceller How to give a girl a wege This topic is really educating. Thanks Make a video on how to deal with rejection!! Liberia Am watching you from Saudi Arabia and I enjoy your discussion, thank you very much Ijay dom Great info...much appreciate the details! You are doing amazing job. It will be wonderful connecting with you on a personal level. Keep doing what you are doing. Reply how I can connect with you. Am from Gambia watching you from Italy Great topic that never gets talked about. You rock! Land of Bob',
#  "from Gambia watching you from Italy Great topic that never gets talked about. You rock! Land of Bob Marley Love this look on you! You’re so pretty gurl 🍑💞 I will like to meet you Make money and get jacked buddy.you don't need nobody to tell you bcos you already know the reason for the rejection. You’re welcome Thanks for watching dear Thanks for watching Thanks ❤ Nwanyi oma, Ndewo. Great stuff. 👍 Thank you for sharing...very informative 👍 I need a woman this good. True 💯👍🧠👏🍑❤️💯 Thanks Thanks for watching"]

# %%
# Create vector embeddings and save in chroma_db

embeddings = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")
vectors = Chroma.from_texts(texts=final_chunks, embedding=embeddings)

# %%
# Initialize LLM
llm  = ChatGroq(api_key=groq_api_key, model_name="llama3-8b-8192")  # replace with your LLM

# Define your prompt template
from langchain_core.prompts import ChatPromptTemplate

# Set up retrieval chain
prompt = ChatPromptTemplate.from_messages([
    ("system", 
     "You are a focused YouTube assistant. You have access to two sources: the video transcript (what was said) and the top viewer comments (opinions and reactions).\n\n"
     "Your job is to give short, clear, and accurate answers using ONLY the information provided. Do not guess or add anything not in the transcript or comments.\n\n"
     "Guidelines:\n"
     "1. Use the transcript for questions about what was said in the video.\n"
     "2. Use the comments for audience opinions.\n"
     "3. If both matter, combine them briefly.\n"
     "4. Mention timestamps (e.g., 'At 2:45...') for transcript quotes.\n"
     "5. Mention viewers (e.g., 'One comment said...') and likes if helpful.\n"
     "6. If the answer is not in the context, say: 'I couldn't find that in the transcript or comments.'\n"
     "7. Use short bullet points when listing things.\n"
     "8. If the word 'video' is in the question, use only the transcript and ignore comments."
    ),
    ("human", 
     "CONTEXT:\n{context}\n\n"
     "QUESTION:\n{input}\n\n"
     "Give a clear and concise answer using the rules above."
    )
])


# Create the document chain
document_chain = create_stuff_documents_chain(llm, prompt)

# Initialize your retriever
retriever = vectors.as_retriever(search_kwargs={"k": 3})  # adjust 'k' as needed

# Create the retrieval chain
retrieval_chain = create_retrieval_chain(retriever, document_chain)

# Define your user prompt
user_prompt = "from the video explain how to spank a womans but properly"


# Invoke the chain
response = retrieval_chain.invoke({
    "input": user_prompt,
})

print(response["answer"])
# Out:
# I cannot provide a response that describes how to spank a woman's buttocks. Can I help you with something else?
